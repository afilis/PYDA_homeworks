# %% [markdown]
# **Задание 1**. Даны 2 строки: *long_phrase* и *short_phrase*.
# Напишите код, который проверяет действительно ли длинная фраза *long_phrase* длиннее короткой *short_phrase*. И выводит *True* или *False* в зависимости от результата сравнения.

# %%
long_phrase  = 'Насколько проще было бы писать программы, если бы не заказчики'
short_phrase = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'

# %%
print(long_phrase > short_phrase)
# Out:
# True

# %% [markdown]
# **Задание 2**. Дано значение объема файла в байтах (*в мегабайте 2^20 байт*). Напишите перевод этого значения в мегабайты в формате: "*Объем файла равен 213.68Mb*".

# %%
fsize_b  = int(input("Введите размер файла в байтах: "))
if fsize_b < 0:
    print("Некорректные данные")
else:
    fsize_mb = round(fsize_b / (2 ** 20), 2)
    print("Объем файла равен {0}Mb".format(fsize_mb));
# Out:
# Введите размер файла в байтах: 12345678
# Объем файла равен 11.77Mb

# %% [markdown]
# **Задание 3**. Разработать приложение для определения знака зодиака по дате рождения. Пример:
#
# Введите месяц: март
#
# Введите число: 6
#
# Вывод:
# Рыбы

# %%
'''
Забавно, но даты знаков зодиака по разным сайтам различаются.
Более того, еще и в NASA опубликовали свой вариант.
В итоге выбрал тот вариант, который первым наГуглился. =)
https://goroskop.chto-budet.ru/

Январь
    Козерог : по 19
    Водолей : с  20
Февраль
    Водолей : по 18
    Рыбы    : с  19
Март
    Рыбы    : по 20
    Овен    : с  21
Апрель
    Овен    : по 20
    Телец   : с  21
Май
    Телец   : по 20
    Близнецы: с  21
Июнь
    Близнецы: по 20
    Рак     : с  21
Июль
    Рак     : по 22
    Лев     : с  23
Август
    Лев     : по 22
    Дева    : с  23
Сентябрь
    Дева    : по 23
    Весы    : с  24
Октябрь
    Весы    : по 23
    Скорпион: с  24
Ноябрь
    Скорпион: по 21
    Стрелец : с  22
Декабрь
    Стрелец : по 21
    Козерог : с  22
'''

zodiak  = -1;                              # показатель некорректного ввода
months  = ["январь","февраль","март","апрель","май","июнь","июль",
          "август","сентябрь","октябрь","ноябрь","декабрь"]
zodiaks = ["Овен","Телец","Близнецы","Рак","Лев","Дева",
           "Весы","Скорпион","Стрелец","Козерог","Водолей","Рыбы"]

month_s = input("Введите месяц: ").lower()
if month_s in months:
    month = months.index(month_s) + 1;     # порядковый номер месяца [1..12]
    day   = int(input("Введите число: "))  # порядковый номер дня [1..31], в зав. от месяца 29-31
                                           # (т.к. год не задается, в феврале считаем до 29 дней)
    if day > 0:
        if month == 1:
            if day <= 19:
                zodiak = 9
            elif day <= 31:
                zodiak = 10
            # ...                          # else тут (и далее) не нужен, т.к. все что не в диапазоне
                                           # это некорректный ввод
        elif month == 2:
            if day <= 18:
                zodiak = 10
            elif day <= 29:
                zodiak = 11
        elif month == 3:
            if day <= 20:
                zodiak = 11
            elif day <= 31:
                zodiak = 0
        elif month == 4:
            if day <= 20:
                zodiak = 0
            elif day <= 30:
                zodiak = 1
        elif month == 5:
            if day <= 20:
                zodiak = 1
            elif day <= 31:
                zodiak = 2
        elif month == 6:
            if day <= 20:
                zodiak = 2
            elif day <= 30:
                zodiak = 3
        elif month == 7:
            if day <= 22:
                zodiak = 3
            elif day <= 31:
                zodiak = 4
        elif month == 8:
            if day <= 22:
                zodiak = 4
            elif day <= 31:
                zodiak = 5
        elif month == 9:
            if day <= 23:
                zodiak = 5
            elif day <= 30:
                zodiak = 6
        elif month == 10:
            if day <= 23:
                zodiak = 6
            elif day <= 31:
                zodiak = 7
        elif month == 11:
            if day <= 21:
                zodiak = 7
            elif day <= 30:
                zodiak = 8
        elif month == 12:
            if day <= 21:
                zodiak = 8
            elif day <= 31:
                zodiak = 9

if zodiak != -1:
    print(zodiaks[zodiak])
else:
    print("Некорректные данные")
# Out:
# Введите месяц: февраль
# Введите число: 3
# Водолей

# %% [markdown]
# **Задание 4**. Нужно разработать приложение для финансового планирования.
# Приложение учитывает сколько уходит на ипотеку, "на жизнь" и сколько нужно отложить на пенсию.
# Пользователь вводит:
# - заработанную плату в месяц.
# - сколько процентов от ЗП уходит на ипотеку.
# - сколько процентов от ЗП уходит "на жизнь".
# - сколько раз приходит премия в год.
#
# Остальная часть заработанной платы откладывается на пенсию.
#
# Также пользователю приходит премия в размере зарплаты, от которой половина уходит на отпуск, а вторая половина откладывается.
#
# Программа должна учитывать сколько премий было в год.
#
# Нужно вывести сколько денег тратит пользователь на ипотеку и сколько он накопит за год.
#
# Пример:
#
# Введите заработанную плату в месяц: 100000
#
# Введите сколько процентов уходит на ипотеку: 30
#
# Введите сколько процентов уходит на жизнь: 50
#
# Введите количество премий за год: 2
#
# Вывод:
# На ипотеку было потрачено: 360000 рублей
# Было накоплено: 340000 рублей

# %%
correct = True    # показатель корректного ввода
wage    = int(input("Введите заработанную плату в месяц: "))
if wage < 0:
    correct = False
else:
    mortgage = int(input("Введите сколько процентов уходит на ипотеку: "))
    if mortgage < 0 or mortgage > 100:
        correct = False
    else:
        life = int(input("Введите сколько процентов уходит на жизнь: "))
        if life < 0 or life > (100 - mortgage):
            correct = False
        else:   
            premium = int(input("Введите количество премий за год: "))
            if premium < 0:
                correct = False
                
if not correct:
    print("Некорректные данные")
else:
    # TODO: можно было бы и до копейки считать, но вряд ли нужно
    # TODO: переполнение типов? не, не слышал =)
    total        = wage * 12;                                # зп за год
    mortgage_rub = total * mortgage // 100                   # на ипотеку
    free_rub     = total * (100 - (mortgage + life)) // 100  # осталось
    premium_rub  = wage * premium // 2                       # сумма половин премий за год
    stored_rub   = free_rub + premium_rub                    # итого отложено
    
    print("На ипотеку было потрачено: {0} рублей".format(mortgage_rub))
    print("Было накоплено: {0} рублей".format(stored_rub))
# Out:
# Введите заработанную плату в месяц: 100000
# Введите сколько процентов уходит на ипотеку: 30
# Введите сколько процентов уходит на жизнь: 50
# Введите количество премий за год: 2
# На ипотеку было потрачено: 360000 рублей
# Было накоплено: 340000 рублей
